# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from collections import defaultdict

# %%
files = glob.glob('../Solution/Easy*.csv')
files.sort()
files
# Out:
# ['../Solution\\Easy Policy.csv',
#  '../Solution\\Easy Q-Learning L0.1 E0.3.csv',
#  '../Solution\\Easy Q-Learning L0.1 E0.5.csv',
#  '../Solution\\Easy Q-Learning L0.1 E0.7.csv',
#  '../Solution\\Easy Q-Learning L0.9 E0.3.csv',
#  '../Solution\\Easy Q-Learning L0.9 E0.5.csv',
#  '../Solution\\Easy Q-Learning L0.9 E0.7.csv',
#  '../Solution\\Easy Value.csv']

# %%
a = np.array(files)
b = [0,3,7]
files = list(a[b])
files = dict(enumerate(files))
files
# Out:
# {0: '../Solution\\Easy Policy.csv',
#  1: '../Solution\\Easy Q-Learning L0.1 E0.7.csv',
#  2: '../Solution\\Easy Value.csv'}

# %%
dfs = defaultdict(int)
for indx, f in files.items():
    dfs[indx] = pd.read_csv(f)

# %%
dfs[0][:5]
# Out:
#    iter       time  reward  steps  convergence  policy
# 0     1   1.538645  -869.0  962.0    79.668000   False
# 1     2   4.884349    50.0   52.0    68.112269   False
# 2     3   5.841166    85.0   17.0    65.534748   False
# 3     4  10.991167    93.0    9.0    56.272747   False
# 4     5   8.551755    93.0    9.0    37.904453    True

# %% [markdown]
# ## Iterations vs Time

# %%
ax = plt.subplot(111)

plt.plot(dfs[0]['iter'],dfs[0]['time'], label = "Policy Iteration")
plt.plot(dfs[1]['iter'],dfs[1]['time'], label = "Q-Learning L0.1 E0.7")
plt.plot(dfs[2]['iter'],dfs[2]['time'], label = "Value Iteration")
    
#plt.ylim(0, 20)
plt.xlim(0, 100)
plt.ylabel("Time (in ms)")
plt.xlabel("Iterations")
plt.title('Easy Comparison: Iterations vs. Time')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Steps

# %%
ax = plt.subplot(111)

plt.plot(dfs[0]['iter'],dfs[0]['steps'], label = "Policy Iteration")
plt.plot(dfs[1]['iter'],dfs[1]['steps'], label = "Q-Learning L0.1 E0.7")
plt.plot(dfs[2]['iter'],dfs[2]['steps'], label = "Value Iteration")

plt.ylim(0, 100)
plt.xlim(0, 100)
plt.ylabel("Steps")
plt.xlabel("Iterations")
plt.title('Easy Comparison: Iterations vs. Steps')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Convergence

# %%
ax = plt.subplot(111)

plt.plot(dfs[0]['iter'],dfs[0]['convergence'], label = "Policy Iteration")
plt.plot(dfs[1]['iter'],dfs[1]['convergence'], label = "Q-Learning L0.1 E0.7")
plt.plot(dfs[2]['iter'],dfs[2]['convergence'], label = "Value Iteration")

#plt.ylim(0, 10)
plt.xlim(0, 100)
plt.ylabel("Convergence")
plt.xlabel("Iterations")
plt.title('Easy Comparison: Iterations vs. Convergence')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Reward

# %%
ax = plt.subplot(111)

plt.plot(dfs[0]['iter'],dfs[0]['reward'], label = "Policy Iteration")
plt.plot(dfs[1]['iter'],dfs[1]['reward'], label = "Q-Learning L0.1 E0.7")
plt.plot(dfs[2]['iter'],dfs[2]['reward'], label = "Value Iteration")

plt.ylim(-100, 100)
plt.xlim(0, 100)
plt.ylabel("Reward")
plt.xlabel("Iterations")
plt.title('Easy Comparison: Iterations vs. Reward')
ax.legend()
plt.show()
