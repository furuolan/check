# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from collections import defaultdict

# %%
files = glob.glob('../Solution/Easy Q-Learning*.csv')
files.sort()
#File name beginining
nb = 27
#File name ending
ne = -4
#Output file
#name = 'tsp.csv'

# %%
files = dict(enumerate(files))
files
# Out:
# {0: '../Solution\\Easy Q-Learning L0.1 E0.3.csv',
#  1: '../Solution\\Easy Q-Learning L0.1 E0.5.csv',
#  2: '../Solution\\Easy Q-Learning L0.1 E0.7.csv',
#  3: '../Solution\\Easy Q-Learning L0.9 E0.3.csv',
#  4: '../Solution\\Easy Q-Learning L0.9 E0.5.csv',
#  5: '../Solution\\Easy Q-Learning L0.9 E0.7.csv'}

# %%
dfs = defaultdict(int)
for indx, f in files.items():
    dfs[indx] = pd.read_csv(f)

# %%
dfs[0][:5]
# Out:
#    iter        time  reward  steps  convergence  policy
# 0     1  369.442544    30.0   63.0     9.990000     NaN
# 1     2    7.490730     5.0   88.0     9.791900     NaN
# 2     3    1.094972    55.0   47.0     9.441439     NaN
# 3     4    4.435544   -43.0  145.0     9.011324     NaN
# 4     5    4.991320    63.0   39.0     8.472931     NaN

# %%
# df_concats = []
# for x in range(0,len(dfs),trials):
#     df_concat = pd.concat([dfs[x+i] for i in range(trials)])
#     by_row_index = df_concat.groupby(df_concat.index)
#     df_means = by_row_index.mean()
#     df_concats.append(df_means.loc[r])

# %% [markdown]
# ## Iterations vs Time

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['time']], label = files[indx][nb:ne])

plt.ylim(0, 1)
plt.xlim(0, 600)
plt.ylabel("Time (in ms)")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Time')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Steps

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['steps']], label = files[indx][nb:ne])

plt.ylim(8, 200)
plt.xlim(0, 600)
plt.ylabel("Steps")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Steps')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Convergence

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['convergence']], label = files[indx][nb:ne])

plt.ylim(0, 10)
plt.xlim(0, 600)
plt.ylabel("Convergence")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Convergence')
ax.legend()
plt.show()

# %% [markdown]
# ## Iterations vs Reward

# %%
ax = plt.subplot(111)

for indx, d in dfs.items():
    ax.plot(d[['iter']],d[['reward']], label = files[indx][nb:ne])

plt.ylim(-100, 100)
plt.ylabel("Reward")
plt.xlabel("Iterations")
plt.title('Q-Learning: Iterations vs. Reward')
ax.legend()
plt.show()
